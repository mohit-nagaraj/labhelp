# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import SGD, Adadelta, Adam, RMSprop, Adagrad, Nadam, Adamax

# %%
# Load in the data
cifar100 = tf.keras.datasets.cifar100

# Distribute it to train and test set
(x_train, y_train), (x_val, y_val) = cifar100.load_data()

# %%
y_train = tf.one_hot(y_train, depth=y_train.max()+1, dtype=tf.float64)
y_val = tf.one_hot(y_val, depth=y_val.max()+1, dtype=tf.float64)

# %%
y_train=tf.squeeze(y_train)
y_val=tf.squeeze(y_val)

# %%
def create_model(opt):
  model = tf.keras.models.Sequential([
        layers.Conv2D(16, (3, 3), activation='relu', input_shape=(32, 32, 3), padding='same'),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D(2, 2),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.BatchNormalization(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.3),
        layers.BatchNormalization(),
        layers.Dense(100, activation='softmax')
  ])
  return model

# %%
model = create_model(Adam)
model.summary()
# Out:
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_104 (Conv2D)                  │ (None, 32, 32, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_105 (Conv2D)                  │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_106 (Conv2D)                  │ (None, 32, 32, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_26 (MaxPooling2D)      │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_107 (Conv2D)                  │ (None, 16, 16, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_26 (Flatten)                 │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_78 (Dense)                     │ (None, 256)                 │       8,388,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_52               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_79 (Dense)                     │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_53               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_80 (Dense)                     │ (None, 100)                 │          25,700 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,579,844 (32.73 MB)
#  Trainable params: 8,578,820 (32.73 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def create_callbacks(opt):
  checkpoint_path = 'checkpoints/optimizers_best_' + opt + '.keras'
  callbacks = [
      EarlyStopping(monitor='val_accuracy', patience=3, mode='max', verbose=1),  # Use 'val_accuracy'
      ModelCheckpoint(checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)  # Use 'val_accuracy'
  ]
  return callbacks

# %%
opts = dict({
    'sgd': SGD(),
    'sgd-0001': SGD(learning_rate=0.01, decay=0.0001),
    'adam': Adam(),
    'adadelta': Adadelta(),
    'rmsprop': RMSprop(),
    'rmsprop-0001': RMSprop(learning_rate=0.0001),
    'nadam': Nadam(),
    'adamax': Adamax()
})

# %%
batch_size = 64
n_epochs = 30
results = []

# Loop through the optimizers
for opt in opts:
    print("********************Now model has taken "+ opt +" as Optimizer********************")
    model = create_model(opt)  # Assuming create_model is defined elsewhere
    callbacks = create_callbacks(opt)  # Assuming create_callbacks is defined elsewhere
    model.compile(loss='mse', optimizer=opts[opt], metrics=['accuracy'])

    # Use X_train and y_train directly without .values
    hist = model.fit(x_train, y_train, batch_size=batch_size, epochs=n_epochs,
                     validation_data=(x_val, y_val), verbose=1, callbacks=callbacks)

    best_epoch = np.argmax(hist.history['val_accuracy'])
    best_acc = hist.history['val_accuracy'][best_epoch]

    # Create a new model instance to load weights
    best_model = create_model(opt)

    # Load the model weights with the highest validation accuracy
    best_model.load_weights('checkpoints/optimizers_best_' + opt + '.keras')
    best_model.compile(loss='mse', optimizer=opts[opt], metrics=['accuracy'])

    # Evaluate the model
    print("********************Now model gets evaluated********************")
    score = best_model.evaluate(x_val, y_val, verbose=1)
    results.append([opt, best_epoch, best_acc, score[1]])  # score[1] corresponds to accuracy
# Out:
# ********************Now model has taken sgd as Optimizer********************
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0103 - loss: 0.0102
# Epoch 1: val_accuracy improved from -inf to 0.01180, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0
saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 72ms/step - accuracy: 0.0360 - loss: 0.0100 - val_accuracy: 0.0473 - val_loss: 0.0099
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0364 - loss: 0.0100
# Epoch 17: val_accuracy did not improve from 0.04730
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.0364 - loss: 0.0100 - val_accuracy: 0.0470 - val_loss: 0.0099
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0380 - loss: 0.0100
# Epoch 18: val_accuracy improved from 0.04730 to 0.05000, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.0380 - loss: 0.0100 - val_accuracy: 0.0500 - val_loss: 0.0099
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0408 - loss: 0.0100
# Epoch 19: val_accuracy improved from 0.05000 to 0.05020, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 73ms/step - accuracy: 0.0408 - loss: 0.0100 - val_accuracy: 0.0502 - val_loss: 0.0099
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0383 - loss: 0.0100
# Epoch 20: val_accuracy improved from 0.05020 to 0.05180, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.0383 - loss: 0.0100 - val_accuracy: 0.0518 - val_loss: 0.0099
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0394 - loss: 0.0100
# Epoch 21: val_accuracy improved from 0.05180 to 0.05280, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.0394 - loss: 0.0100 - val_accuracy: 0.0528 - val_loss: 0.0099
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0419 - loss: 0.0100
# Epoch 22: val_accuracy improved from 0.05280 to 0.05610, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.0419 - loss: 0.0100 - val_accuracy: 0.0561 - val_loss: 0.0099
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0433 - loss: 0.0100
# Epoch 23: val_accuracy improved from 0.05610 to 0.05660, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 71ms/step - accuracy: 0.0433 - loss: 0.0100 - val_accuracy: 0.0566 - val_loss: 0.0099
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0453 - loss: 0.0100
# Epoch 24: val_accuracy improved from 0.05660 to 0.05850, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 83s 72ms/step - accuracy: 0.0453 - loss: 0.0100 - val_accuracy: 0.0585 - val_loss: 0.0098
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0470 - loss: 0.0100
# Epoch 25: val_accuracy improved from 0.05850 to 0.06020, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.0470 - loss: 0.0100 - val_accuracy: 0.0602 - val_loss: 0.0098
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0469 - loss: 0.0100
# Epoch 26: val_accuracy did not improve from 0.06020
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 71ms/step - accuracy: 0.0469 - loss: 0.0100 - val_accuracy: 0.0596 - val_loss: 0.0098
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0484 - loss: 0.0099
# Epoch 27: val_accuracy improved from 0.06020 to 0.06290, saving model to checkpoints/optimizers_best_sgd.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 72ms/step - accuracy: 0.0484 - loss: 0.0099 - val_accuracy: 0.0629 - val_loss: 0.0098
# Epoch 28/30
# 570/782 ━━━━━━━━━━━━━━━━━━━━ 14s 66ms/step - accuracy: 0.0494 - loss: 0.0099

# %%
results_df = pd.DataFrame(results, columns=["Optimizer", "Best Epoch", "Best Validation Accuracy", "Validation Accuracy"])
print("\n******************** Results Summary ********************")
print(results_df)
# Out:
# ******************** Results Summary ********************
#       Optimizer  Best Epoch  Best Validation Accuracy  Validation Accuracy
# 0           sgd           4                    0.0197               0.0197
# 1      sgd-0001           4                    0.0216               0.0216
# 2          adam           4                    0.2154               0.2154
# 3      adadelta           4                    0.0093               0.0093
# 4       rmsprop           4                    0.1921               0.1921
# 5  rmsprop-0001           4                    0.1052               0.1052
# 6         nadam           4                    0.1886               0.1886
# 7        adamax           4                    0.3032               0.3032
